# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine


engine = create_engine("mysql://admin:pooiiioop@book.cvmrepjyvhmd.ap-northeast-2.rds.amazonaws.com/kyobobook", convert_unicode=True)
conn = engine.connect()

review = pd.read_sql_table('reviews1', conn)
# Out:
# C:\Users\leeej\AppData\Local\Temp/ipykernel_12856/3766054926.py:6: SADeprecationWarning: The create_engine.convert_unicode parameter and corresponding dialect-level parameters are deprecated, and will be removed in a future release.  Modern DBAPIs support Python Unicode natively and this parameter is unnecessary.
#   engine = create_engine("mysql://admin:pooiiioop@book.cvmrepjyvhmd.ap-northeast-2.rds.amazonaws.com/kyobobook", convert_unicode=True)

# %%
review
# Out:
#         index book_categories                                     book_name  \
# 0           0            자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 1           1            자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 2           2            자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 3           3            자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 4           4            자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# ...       ...             ...                                           ...
# 810470   1548         중/고등참고서                          Bricks 중학 Grammar. 3
# 810471   1549         중/고등참고서                          Bricks 중학 Grammar. 3
# 810472   1550         중/고등참고서                          Bricks 중학 Grammar. 3
# 810473   1551         중/고등참고서                          Bricks 중학 Grammar. 3
# 810474   1552         중/고등참고서                          Bricks 중학 Grammar. 3
#
# ...

# %%
review = review.drop('index', axis=1)

# %%
review
# Out:
#       book_categories                                 book_name book_ratings  \
# 0              취업/수험서                           2022 신용한 행정학 세트            4
# 1              취업/수험서                           2022 신용한 행정학 세트            4
# 2              취업/수험서                           2022 신용한 행정학 세트            4
# 3              취업/수험서                           2022 신용한 행정학 세트            4
# 4              취업/수험서                           2022 신용한 행정학 세트            3
# ...               ...                                       ...          ...
# 44689          컴퓨터/IT  윈도우 10+엑셀 파워포인트 워드 2016 한글 2014 무작정 따라하기            4
# 44690          컴퓨터/IT  윈도우 10+엑셀 파워포인트 워드 2016 한글 2014 무작정 따라하기            4
# 44691          컴퓨터/IT  윈도우 10+엑셀 파워포인트 워드 2016 한글 2014 무작정 따라하기            4
# 44692          컴퓨터/IT  윈도우 10+엑셀 파워포인트 워드 2016 한글 2014 무작정 따라하기            4
# 44693          컴퓨터/IT  윈도우 10+엑셀 파워포인트 워드 2016 한글 2014 무작정 따라하기            1
#
# ...

# %%
review = review.drop_duplicates(keep = 'first')

# %%
review
# Out:
#        book_categories                                     book_name  \
# 0                 자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 1                 자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 2                 자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 3                 자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 4                 자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# ...                ...                                           ...
# 810470         중/고등참고서                          Bricks 중학 Grammar. 3
# 810471         중/고등참고서                          Bricks 중학 Grammar. 3
# 810472         중/고등참고서                          Bricks 중학 Grammar. 3
# 810473         중/고등참고서                          Bricks 중학 Grammar. 3
# 810474         중/고등참고서                          Bricks 중학 Grammar. 3
#
#        book_ratings                                       book_reviews
# ...

# %%
review = review.reset_index()

# %%
review = review.drop('index', axis=1)

# %%
review
# Out:
#       book_categories                                     book_name  \
# 0                자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 1                자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 2                자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 3                자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# 4                자기계발  좋아하는 것보다 잘하는 것에 승부를 걸어라 약손명가 김현숙 대표의 남다른 이야기
# ...               ...                                           ...
# 66835         중/고등참고서                          Bricks 중학 Grammar. 3
# 66836         중/고등참고서                          Bricks 중학 Grammar. 3
# 66837         중/고등참고서                          Bricks 중학 Grammar. 3
# 66838         중/고등참고서                          Bricks 중학 Grammar. 3
# 66839         중/고등참고서                          Bricks 중학 Grammar. 3
#
#       book_ratings                                       book_reviews
# 0                4                                         잘 읽고 있어요..
# ...

# %%
from sqlalchemy import create_engine
import pymysql

pymysql.install_as_MySQLdb()
engine = create_engine("mysql://admin:pooiiioop@book.cvmrepjyvhmd.ap-northeast-2.rds.amazonaws.com/kyobobook")

data_df = pd.DataFrame(review)
data_df.to_sql('reviews', engine, if_exists='append')
